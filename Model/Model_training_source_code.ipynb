# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re

# %% [markdown]
# ## Data Understanding

# %%
#Connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Data_directory
data_dir = '/content/drive/MyDrive/formalAndInformal/training_labeled.csv'
dataset = pd.read_csv(data_dir)

# %%
dataset.head(10)
# Out:
#   Subreddit                                  Original Sentence  \
# 0  antiwork                         r/isthisanothersubifellfor
# 1  antiwork  Sounds like you’re working car sales persons s...
# 2  antiwork        Boss watching too much Rupert on Ted Lasso.
# 3  antiwork  Immature and racist who could have guessed sta...
# 4  antiwork                         Reply “ you can get sued”.
# 5  antiwork                    “Specially” to the interns? LOL
# 6  antiwork  &gt;if **they** deem them No, the policy agree...
# 7  antiwork               Ah, we’re at the cult compound stage
# 8  antiwork                       &gt; Decent people So, rare.
# 9  antiwork              I promise thoes kids won’t be working
#
#                                      Formal Sentence
# 0                    Is this another sub I fell for?
# 1  It appears that you are working a schedule sim...
# 2  Boss is watching a lot of the show Ted Lasso, ...
# 3  People can be immature and have prejudices, bu...
# 4               It is possible to face legal action.
# 5  To the interns, this is especially for you! Ha...
# 6  If it is determined that they do not agree wit...
# 7                   We have arrived at the compound.
# 8           People of good character are not common.
# 9            The children will not be employed here.

# %%
dataset["Original Sentence"][1]
# Out:
# 'Sounds like you’re working car sales persons schedule'

# %%
dataset.shape
# Out:
# (2999, 3)

# %% [markdown]
# ## Data Preprocessing

# %%
#remove source(first column)
df = dataset.iloc[:,1:]
df.head()
# Out:
#                                    Original Sentence  \
# 0                         r/isthisanothersubifellfor
# 1  Sounds like you’re working car sales persons s...
# 2        Boss watching too much Rupert on Ted Lasso.
# 3  Immature and racist who could have guessed sta...
# 4                         Reply “ you can get sued”.
#
#                                      Formal Sentence
# 0                    Is this another sub I fell for?
# 1  It appears that you are working a schedule sim...
# 2  Boss is watching a lot of the show Ted Lasso, ...
# 3  People can be immature and have prejudices, bu...
# 4               It is possible to face legal action.

# %%
#new df for each column
informal_df = pd.DataFrame()
formal_df = pd.DataFrame()

# Add a 'text' column to each dataframe
informal_df['text'] = pd.DataFrame(df['Original Sentence'])
formal_df['text'] = pd.DataFrame(df['Formal Sentence'])

# Add a label column with value 0 represent informal
informal_df['label'] = 0

# Add a label column with value 1 represent formal
formal_df['label'] = 1

# %%
formal_df
# Out:
#                                                    text  label
# 0                       Is this another sub I fell for?      1
# 1     It appears that you are working a schedule sim...      1
# 2     Boss is watching a lot of the show Ted Lasso, ...      1
# 3     People can be immature and have prejudices, bu...      1
# 4                  It is possible to face legal action.      1
# ...                                                 ...    ...
# 2994  SK authorized the re-export of Krab SPGs conta...      1
# 2995  I would have a high level of confidence in US ...      1
# 2996  Your family could be in danger if a relative r...      1
# 2997  I'm starting to consider that Zapp Branagan ha...      1
# 2998  I was more interested in the science than the ...      1
#
# [2999 rows x 2 columns]

# %%
#Combine the two dataframes
final_df = pd.concat([informal_df, formal_df], axis=0)
final_df = final_df.sample(frac=1).reset_index(drop=True)
final_df
# Out:
#                                                    text  label
# 0     Something should be laughed at judged because ...      0
# 1     “I’m playing both sides so that I always come ...      0
# 2                    They’ll be underwater in a minute.      0
# 3              En voinut olla huomaamatta En huomannut.      1
# 4               Holy shit, Libleft-Authright crossover?      0
# ...                                                 ...    ...
# 5993                       What is Aidan? It is a name.      1
# 5994  It may have been a mistake to purchase 0dte in...      1
# 5995   People from Britain are invited to join for tea.      1
# 5996  People may feel overwhelmed by compliments, an...      1
# 5997  He likely thought that statement would convinc...      1
#
# [5998 rows x 2 columns]

# %%
#Change to lower case
final_df['text'] = final_df['text'].str.lower()

# %%
#remove url
def remove_url(text):
    url_pattern = re.sub(r'https?//\S+|www\.\S+', '', text)
    return url_pattern

final_df['text'] = final_df['text'].apply(remove_url)

# %%
#remove emojis
# !pip install emoji
import emoji
def remove_emojis(text):
    return emoji.demojize(text)

final_df['text'] = final_df['text'].apply(remove_emojis)
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (2.14.1)

# %%
#lemmatization
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
def lemmatize_text(text):
    words = text.split()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

final_df['text'] = final_df['text'].apply(lemmatize_text)
final_df.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                                 text  label
# 0  something should be laughed at judged because ...      0
# 1  “i’m playing both side so that i always come o...      0
# 2                 they’ll be underwater in a minute.      0
# 3           en voinut olla huomaamatta en huomannut.      1
# 4            holy shit, libleft-authright crossover?      0

# %%
#train test split
from sklearn.model_selection import train_test_split
X = final_df['text']
y = final_df['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print("The shape of X_train is ", X_train.shape)
print("The shape of X_test is ", X_test.shape)

print("The shape of y_train is", y_train.shape)
print("The shape of y_test is", y_test.shape)
# Out:
# The shape of X_train is  (4798,)
# The shape of X_test is  (1200,)
# The shape of y_train is (4798,)
# The shape of y_test is (1200,)

# %%
#tokenization
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_word = 3000
embedding_dim = 64
trunc_type='post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words = max_word, oov_token = oov_tok)
tokenizer.fit_on_texts(X_train)
tokenizer.fit_on_texts(X_test)
word_index = tokenizer.word_index

#sequencing
X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)
max_length = 150

#padding
X_train_padded = pad_sequences(X_train_sequences, maxlen=max_length, padding='post')
X_test_padded = pad_sequences(X_test_sequences, maxlen=max_length, padding='post')

# %%
print("X_train_padded:")
print(X_train_padded)
print("\nX_test_padded:")
print(X_test_padded)
# Out:
# X_train_padded:
# [[1931   12    3 ...    0    0    0]
#  [   8   25   13 ...    0    0    0]
#  [  11  147   16 ...    0    0    0]
#  ...
#  [  61   72   51 ...    0    0    0]
#  [ 299  271 1304 ...    0    0    0]
#  [ 333   47    3 ...    0    0    0]]
#
# X_test_padded:
# [[  10 1149    1 ...    0    0    0]
#  [1812    1  463 ...    0    0    0]
#  [   2 1029   80 ...    0    0    0]
#  ...
#  [  76  107   14 ...    0    0    0]
#  [  24   34   31 ...    0    0    0]
#  [ 659    8    1 ...    0    0    0]]

# %% [markdown]
# ## Modelling

# %%
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
BiLSTM_model = tf.keras.Sequential([
      tf.keras.layers.Embedding(input_dim=max_word, output_dim=64, input_shape=(max_length,)),
      tf.keras.layers.SpatialDropout1D(0.5),
      tf.keras.layers.Bidirectional(LSTM(32)),
      tf.keras.layers.Dense(1, activation='sigmoid')])

BiLSTM_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
BiLSTM_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 150, 64)             │         192,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d_1                  │ (None, 150, 64)             │               0 │
# │ (SpatialDropout1D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 216,897 (847.25 KB)
#  Trainable params: 216,897 (847.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

#Training Model
BiLSTM_history = BiLSTM_model.fit(X_train_padded, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data = (X_test_padded, y_test),
                    callbacks = [early_stopping],
                    verbose=1)
# Out:
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 57s 295ms/step - accuracy: 0.6461 - loss: 0.6274 - val_accuracy: 0.8258 - val_loss: 0.3868
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8696 - loss: 0.3184 - val_accuracy: 0.8808 - val_loss: 0.2865
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 43s 178ms/step - accuracy: 0.9189 - loss: 0.2264 - val_accuracy: 0.8875 - val_loss: 0.2749
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9463 - loss: 0.1580 - val_accuracy: 0.8817 - val_loss: 0.3031
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 150ms/step - accuracy: 0.9532 - loss: 0.1257 - val_accuracy: 0.8808 - val_loss: 0.3289
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 41s 151ms/step - accuracy: 0.9661 - loss: 0.0980 - val_accuracy: 0.8725 - val_loss: 0.3559

# %% [markdown]
# ## Evaluation

# %%
predicted_results = BiLSTM_model.predict(X_test_padded)
print(predicted_results)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step
# [[0.03526644]
#  [0.994724  ]
#  [0.0096377 ]
#  ...
#  [0.09164802]
#  [0.99431306]
#  [0.00540767]]

# %%
y_pred = []
threshold_value = 0.55
for  i in predicted_results:
  current_val = i[0]
  if (current_val>=threshold_value):
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
# Evaluation Metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
ans = y_pred
print('Accuracy Score',accuracy_score(y_test,ans)*100,'%')
print('Precision Macro Score',precision_score(y_test,ans,average = 'macro')*100,'%')
print('Recall_Score',recall_score(y_test,ans, average = 'macro')*100,'%')
print('F1_Score',f1_score(y_test,ans, average = 'macro')*100,'%')
# Out:
# Accuracy Score 89.16666666666667 %
# Precision Macro Score 89.20493231544808 %
# Recall_Score 89.19970323358685 %
# F1_Score 89.16663657399049 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

# Plotting the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Informal', 'Formal'],
            yticklabels=['Informal', 'Formal'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of Model')
plt.show()

# %%
inputs = ["we gotta move on, can't waste time anymore!"]
print(inputs)
testing_sequences = tokenizer.texts_to_sequences(inputs)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length, truncating=trunc_type,padding='post')
ans = BiLSTM_model.predict(testing_padded)
print(ans[0][0])

if (ans[0][0]>=threshold_value):
  print("Formal")
else:
  print("Informal")
# Out:
# ["we gotta move on, can't waste time anymore!"]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 0.17647344
# Informal

# %% [markdown]
# ## Save

# %%
# save model
BiLSTM_model.save('/content/drive/MyDrive/formalAndInformal/the_best_model.keras')

# %%
import joblib

# Save the tokenizer
joblib.dump(tokenizer, '/content/drive/MyDrive/formalAndInformal/custom_tokenizer.joblib')
# Out:
# ['/content/drive/MyDrive/formalAndInformal/custom_tokenizer.joblib']
